# %% [markdown]
# <a href="https://colab.research.google.com/github/pvnmahathi/FMML20210264-Labs/blob/main/FMML20210264_FMML_Course_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-13 03:15:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   129MB/s    in 0.5s
#
# 2022-06-13 03:15:12 (129 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3977 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2777 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6298   1611.01144v5  Categorical variables are a natural choice for...  stat
# 15042   1302.4811v1  Regulations in the Building Industry are becom...    cs
# 27271  1703.01025v1  In this study, a multi-task deep neural networ...    cs
# 3420   1703.00986v1  Restricted Boltzmann machines~(RBMs) and condi...    cs
# 20628  1608.06349v1  Reasoning does not work well when done in isol...    cs
# ...             ...                                                ...   ...
# 6957   1708.01977v2  From scientific experiments to online A/B test...  stat
# 7667   1802.07124v3  The easiness at which adversarial instances ca...    cs
# 14951  1505.04197v1  We present an annotation schema as part of an ...    cs
# 1789   1609.02116v2  In a variety of application domains the conten...  stat
# 4690    1206.6473v1  In this paper we introduce a framework for opt...    cs
#
#                                                    title  year  \
# 6298   Categorical Reparameterization with Gumbel-Sof...  2016
# 15042  Towards a Semantic-based Approach for Modeling...  2013
# 27271  A Novel Multi-task Deep Learning Model for Ski...  2017
# 3420   Belief Propagation in Conditional RBMs for Str...  2017
# 20628           Five dimensions of reasoning in the wild  2016
# ...                                                  ...   ...
# 6957   Why Adaptively Collected Data Have Negative Bi...  2017
# 7667   Out-distribution training confers robustness t...  2018
# 14951  Arabic Inquiry-Answer Dialogue Acts Annotation...  2015
# 1789   Ask the GRU: Multi-Task Learning for Deep Text...  2016
# 4690   Compositional Planning Using Optimal Option Mo...  2012
#
#                                                 keywords
# 6298   [categorical, variables, representing, structu...
# 15042  [regulations, increasingly, technical, compone...
# 27271  [different, segmentation, independent, exploit...
# 3420   [restricted, boltzmann, conditional, applicati...
# 20628  [reasoning, isolation, significance, interests...
# ...                                                  ...
# 6957   [scientific, experiments, previously, experime...
# 7667   [adversarial, instances, generated, fundamenta...
# 14951  [annotation, annotated, understanding, includi...
# 1789   [application, recommended, associated, associa...
# 4690   [introduce, framework, composition, abstractio...
#
# [5403 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6298     [categorical, variables, representing, structu...
# 15042    [regulations, increasingly, technical, compone...
# 27271    [different, segmentation, independent, exploit...
# 3420     [restricted, boltzmann, conditional, applicati...
# 20628    [reasoning, isolation, significance, interests...
#                                ...
# 7258     [parametric, objective, determined, parametric...
# 21956    [algorithm, selection, regularized, regression...
# 25581    [degradation, applications, microscopy, denois...
# 11339    [selecting, sequential, quadratic, optimizatio...
# 21939    [prediction, algorithms, bootstrap, algorithm,...
# Name: keywords, Length: 6754, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 9241 words.
# Out of those 4768 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4f7d07fa-a01e-479b-ae5a-d76c267a4916" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f7d07fa-a01e-479b-ae5a-d76c267a4916")) {                    Plotly.newPlot(                        "4f7d07fa-a01e-479b-ae5a-d76c267a4916",                        [{"x":["outperforms","categorical","distribution","unsupervised","generative","prediction","structure","classification","essential","supervised","differentiable","efficient","inability","reparameterization","representing","stochastic","structured","estimators","variables","estimator","documents","particularly","implementation","environmental","constraints","formalizing","components","processes","noncompliance","generated","regulations","compliance","assessments","increasingly","automatically","technical","assessment","important","regulatory","interested","described","implement","characteristic","efficiency","evaluated","classifications","collaboration","evaluation","separately","different","promising","operating","potential","exploiting","segmentation","experimental","detection","commonalities","challenge","performances","differences","international","respectively","independent","dermoscopic","individual","significantly","applications","thousands","larochelle","propagation","boltzmann","interaction","demonstrate","inference","likelihood","guidelines","conditional","restricted","practical","contrastive","dominated","algorithms","isolation","anticipatory","incorporates","reasoning","knowledge","significance","interests","dimensions","perceptual","increasing","dimensionality","efficiently","multimodal","comparing","similarity","algorithm","similarities","preserving","furthermore","probabilities","clustering","reduction","importantly","dimensional","therefore","theoretical","spatially","mathematically","distributions","constraint","probability","simultaneously","posterior","capabilities","traditional","impractical","challenges","specifically","dependent","nonparametric","additional","assumption","synthetic","subsampling","represents","relational","combination","parallelizable","diffusing","partitioning","thresholding","alternates","magnitude","maintaining","competitive","performance","thresholded","benchmarks","incremental","experimentally","reseeding","comparable","ingredients","pipelines","experiments","including","delivering","benchmarked","application","recognition","environments","previously","recognize","transcription","engineered","inexpensively","techniques","technique","resulting","architectures","languages","framework","introduce","remarkably","attention","demonstrating","benchmark","organizations","competitor","functions","reranking","discriminative","predefined","disambiguating","viability","associating","employing","selection","constrained","consistency","covariance","covariates","formulate","optimization","dimension","minimization","predictive","involving","favorably","additionally","maximally","independence","projected","regression","considers","estimation","translate"],"y":[290,11,230,169,128,235,431,594,81,213,22,467,7,2,83,131,109,22,135,46,78,96,144,24,168,5,116,97,1,206,2,2,14,64,197,48,45,414,3,21,77,72,27,184,163,9,11,281,46,856,116,30,177,95,232,451,404,3,182,40,48,20,99,156,2,128,279,482,27,1,80,20,93,656,242,82,16,121,69,152,6,11,675,9,2,37,136,357,19,22,47,28,119,57,178,40,87,166,945,34,66,194,73,173,116,26,207,180,191,25,9,111,105,192,116,48,57,204,8,124,206,103,17,129,77,149,1,64,33,138,3,1,17,14,8,74,48,119,985,0,107,38,59,0,115,6,15,707,280,3,6,284,419,100,110,51,10,8,4,414,314,171,125,118,594,413,12,171,43,225,12,5,258,3,106,22,2,6,8,36,189,69,65,37,4,56,343,82,72,54,63,27,68,9,23,22,123,48,264,23],"type":"bar"},{"x":["outperforms","categorical","distribution","uns ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4768,), (4768, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7838638045891931

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Generic</span> <span style=''>Approach</span> <span style=''>for</span> <span style=''>Escaping</span> <span style=''>Saddle</span> <span style=''>points</span> <br/><br/><span style=''>A</span> <span style=''>central</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>to</span> <span style=''>using</span> <span style=''>first</span> <span style=''>order</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style='background-color:rgba(255, 0, 0, 0.5319148936170213);'>nonconvex</span> <span style=''>problems</span> <span style=''>is</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>First</span> <span style=''>order</span> <span style=''>methods</span> <span style=''>often</span> <span style=''>get</span> <span style=''>stuck</span> <span style=''>at</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>greatly</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>deteriorating</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Typically</span> <span style=''>to</span> <span style=''>escape</span> <span style=''>from</span> <span style=''>saddles</span> <span style=''>one</span> <span style=''>has</span> <span style=''>to</span> <span style=''>use</span> <span style=''>second</span> <span style=''>order</span> <span style=''>methods</span> <span style=''>However</span> <span style=''>most</span> <span style=''>works</span> <span style=''>on</span> <span style=''>second</span> <span style=''>order</span> <span style=''>methods</span> <span style=''>rely</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>extensively</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>Hessian</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>making</span> <span style=''>them</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impractical</span> <span style=''>in</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>settings</span> <span style=''>To</span> <span style=''>tackle</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>generic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizes</span> <span style=''>Hessian</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>while</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>provably</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converging</span> <span style=''>to</span> <span style=''>second</span> <span style=''>order</span> <span style=''>critical</span> <span style=''>points</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>carefully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternates</span> <span style=''>between</span> <span style=''>a</span> <span style=''>first</span> <span style=''>order</span> <span style=''>and</span> <span style=''>a</span> <span style=''>second</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subroutine</span> <span style=''>using</span> <span style=''>th ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hypernetworks</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>explores</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypernetworks</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypernetwork</span> <span style=''>initializes</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>another</span> <span style=''>network</span> <span style=''>which</span> <span style=''>in</span> <span style=''>turn</span> <span style=''>can</span> <span style=''>be</span> <span style=''>employed</span> <span style=''>for</span> <span style=''>typical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>We</span> <span style=''>optimize</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypernetworks</span> <span style=''>to</span> <span style=''>directly</span> <span style=''>maximize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>of</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>given</span> <span style=''>input</span> <span style=''>Using</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>we</span> <span style=''>obtain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>results</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmarks</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.4615384615384615);'>Thresholding</span> <span style=''>and</span> <span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.31114808652246256);'>dimensional</span> <span style=''>data</span> <span style=''>points</span> <span style=''>into</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.31114808652246256);'>dimensional</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.313868613138686);'>dimensions</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>orientations</span> <span style=''>are</span> <span style=''>unknown</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.4615384615384615);'>thresholding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>the</span> <span style=''>data</span> <span style=''>points</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>succeeds</span> <span style=''>even</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>intersect</span> <span style=''>and</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.313868613138686);'>dimensions</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>scale</span> <span style=''>(up</span> <span style=''>to</span> <span style=''>a</span> <span style=''>log</span> <span style=''>factor)</span> <span style=''>linearly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>ambient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimension</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>also</span> <span style=''>succeeds</span> <span style=''>for</span> <span style=''>data</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>GPU</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>acceleration</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>scale</span> <span style=''>Tree</span> <span style=''>Boosting</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>massively</span> <span style=''>parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerating</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>tree</span> <span style=''>building</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>on</span> <span style=''>GPUs</span> <span style=''>(Graphics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processing</span> <span style=''>Units)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>step</span> <span style=''>in</span> <span style=''>Gradient</span> <span style=''>Boosted</span> <span style=''>Decision</span> <span style=''>Tree</span> <span style=''>(GBDT)</span> <span style=''>and</span> <span style=''>random</span> <span style=''>forests</span> <span style=''>training</span> <span style=''>Previous</span> <span style=''>GPU</span> <span style=''>based</span> <span style=''>tree</span> <span style=''>building</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>parallel</span> <span style=''>multi</span> <span style=''>scan</span> <span style=''>or</span> <span style=''>radix</span> <span style=''>sort</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>tree</span> <span style=''>split</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>issues</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>histogram</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximately</span> <span style=''>find</span> <span style=''>the</span> <span style=''>best</span> <span style=''>split</span> <span style=''>is</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>scalable</span> <span style=''>on</span> <span style=''>GPU</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difference</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>GPU</span> <span style=''>based</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>histogram</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>and</span> <span style=''>the</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>histogram</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>in</span> <span style=''>decision</span> <span style=''>tree</span> <span style ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.08842039018250472)
# 	information (0.24921334172435494)
# 	processing (0.10761485210824417)
# 	segmentation (0.07300188797986155)
# 	architecture (0.08653241032095657)
# 	experimental (0.14191315292636877)
# 	different (0.26935179358086847)
# 	detection (0.12712397734424166)
# 	recognition (0.131843926998112)
# 	convolutional (0.1343612334801762)
#
# Some Statistics words are:
# 	estimation (0.16719101123595506)
# 	statistical (0.1501123595505618)
# 	stochastic (0.13797752808988764)
# 	variables (0.14247191011235955)
# 	algorithm (0.4)
# 	theoretical (0.1644943820224719)
# 	distribution (0.18337078651685393)
# 	dimensional (0.17707865168539325)
# 	inference (0.19550561797752808)
# 	regression (0.17887640449438202)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="044009d7-1967-4320-9b07-cd9906191253" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("044009d7-1967-4320-9b07-cd9906191253")) {                    Plotly.newPlot(                        "044009d7-1967-4320-9b07-cd9906191253",                        [{"x":["outperforms","categorical","distribution","unsupervised","generative","prediction","structure","classification","essential","supervised","differentiable","efficient","inability","reparameterization","representing","stochastic","structured","estimators","variables","estimator","documents","particularly","implementation","environmental","constraints","formalizing","components","processes","noncompliance","generated","regulations","compliance","assessments","increasingly","automatically","technical","assessment","important","regulatory","interested","described","implement","characteristic","efficiency","evaluated","classifications","collaboration","evaluation","separately","different","promising","operating","potential","exploiting","segmentation","experimental","detection","commonalities","challenge","performances","differences","international","respectively","independent","dermoscopic","individual","significantly","applications","thousands","larochelle","propagation","boltzmann","interaction","demonstrate","inference","likelihood","guidelines","conditional","restricted","practical","contrastive","dominated","algorithms","isolation","anticipatory","incorporates","reasoning","knowledge","significance","interests","dimensions","perceptual","increasing","dimensionality","efficiently","multimodal","comparing","similarity","algorithm","similarities","preserving","furthermore","probabilities","clustering","reduction","importantly","dimensional","therefore","theoretical","spatially","mathematically","distributions","constraint","probability","simultaneously","posterior","capabilities","traditional","impractical","challenges","specifically","dependent","nonparametric","additional","assumption","synthetic","subsampling","represents","relational","combination","parallelizable","diffusing","partitioning","thresholding","alternates","magnitude","maintaining","competitive","performance","thresholded","benchmarks","incremental","experimentally","reseeding","comparable","ingredients","pipelines","experiments","including","delivering","benchmarked","application","recognition","environments","previously","recognize","transcription","engineered","inexpensively","techniques","technique","resulting","architectures","languages","framework","introduce","remarkably","attention","demonstrating","benchmark","organizations","competitor","functions","reranking","discriminative","predefined","disambiguating","viability","associating","employing","selection","constrained","consistency","covariance","covariates","formulate","optimization","dimension","minimization","predictive","involving","favorably","additionally","maximally","independence","projected","regression","considers","estimation","translate","according","translates","hyperplane","robustness","information","scientific","correlations","numerical","bottleneck","coefficient","hypothesis","correlation","indicators","expression","satisfies","postulate","canonical","discovering","fundamental","statistically","interactions","discovers","decomposes","contribute","importance","explanation","automatic","analyzing","convolutional","understanding","maintained","occurrences","connections","approaches","scalability","demonstrated","addressing","interpretability","continuous","solutions","developing","irregular","optimized","relationships","evolutionary","effective","initialize","appropriate","alternative","selecting","calculating","attractive","competing","financial", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	thresholded
# 	reseeding
# 	postulate
# 	projectorg
# 	hydrology
# 	climatology
# 	polyhedral
# 	nomination
# 	coalescent
# 	nonstandard
# 	registers
# 	superlinear
# 	clarified
# 	repeatmulti
# 	reparametrizations
# 	nonadaptive
# 	metabolites
# 	irregularly
# 	normalizer
# 	metabolite
# Some words which never appear in Statistics papers:
# 	regulations
# 	compliance
# 	anticipatory
# 	inexpensively
# 	disambiguating
# 	associating
# 	pseudoinverse
# 	unimportant
# 	judgement
# 	binarizing
# 	betterment
# 	legitimately
# 	superpixel
# 	consequent
# 	inflected
# 	occupations
# 	newspaper
# 	diachronic
# 	sharpening
# 	valuation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 2.736127831892306e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7342709104367136

# %% [markdown]
# ### Experimented with various values for parameters and tried to analyse the results
